# %%
import torch
X = torch.randn(100, 1)
X
# Out:
# tensor([[ 0.1994],
#         [-0.1520],
#         [ 0.9389],
#         [ 1.7853],
#         [ 1.1686],
#         [-0.1381],
#         [ 0.2329],
#         [ 0.4041],
#         [-0.2669],
#         [ 0.5327],
#         [-0.4568],
#         [-1.8660],
#         [ 0.8140],
#         [ 1.1729],
#         [ 1.4338],
#         [ 1.3684],
#         [-0.2329],
#         [ 0.6062],
#         [ 0.8590],
#         [-0.4431],
#         [-1.2592],
#         [-0.2317],
#         [-1.0018],
#         [-1.6350],
#         [ 1.2005],
#         [-0.2541],
#         [-0.8508],
#         [-0.2151],
#         [-0.6675],
#         [ 1.0474],
#         [-3.8329],
#         [-0.5141],
#         [-0.2040],
#         [ 0.0507],
#         [-1.0420],
#         [ 0.0245],
#         [ 0.9246],
#         [ 0.6954],
#         [ 0.2493],
#         [-0.2990],
#         [-0.0265],
#         [-1.5715],
#         [-0.5283],
#         [-1.0429],
#         [ 0.1388],
#         [-0.3369],
#         [-0.3327],
# ...
